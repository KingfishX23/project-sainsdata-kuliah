# %%
import pandas as pd
import numpy as np
#HALO JEMS AKU FELI
#halo brooo ini epin
#* open file csv
dataFrameTwitter = pd.read_csv('TRANSLATED-covid-sentiment.csv')

#* ilangin kolom2 berikut
columns = ['mentions', 'conversation_id', 'user_id', 'hashtags']
dataFrameTwitter.drop(columns, inplace=True, axis=1)




"""
#* Convert date and time column to unix timestamp
# This Process converts, and then delete the old date and time columns
# in exchange for a new column (timestamps)
"""

# Declare variable timeStamps untuk ngegabungin dua kolom tersebut
# "2020-05-07 23:58:29"
timeStamps = dataFrameTwitter['date'] + " " + dataFrameTwitter['time']

# Convert String menjadi bentuknya integer!
timeStamps = pd.to_datetime(timeStamps)

# Set data yang udah ada ke kolom timestamps, sekaligus diubah formnya
#dataFrameTwitter['timestamps'] = timeStamps.values.astype(np.int64) // (10 ** 8)

# Delete the old values
#columns = ['date', 'time']
#dataFrameTwitter.drop(columns, inplace=True, axis=1)



"""
#* Print the mean, median, mode of retweets_count and likes_count
"""
print('retweets_count avg =', dataFrameTwitter["retweets_count"].mean())
print('retweets_count median =', dataFrameTwitter["retweets_count"].median())
print('retweets_count mode =', dataFrameTwitter["retweets_count"].mode())
print('\n\n') #ini spasi
print('likes_count avg =', dataFrameTwitter["likes_count"].mean())
print('likes_count median =', dataFrameTwitter["likes_count"].median())
print('likes_count mode =', dataFrameTwitter["likes_count"].mode())
print('\n\n') #ini spasi
# Out:
# retweets_count avg = 2.592136261474722
# retweets_count median = 0.0
# retweets_count mode = 0    0
# dtype: int64
#
#
#
# likes_count avg = 7.686100354734761
# likes_count median = 0.0
# likes_count mode = 0    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

"""
#* Mencoba COUNTIF dan COUNTIFS di kolom likes_count yang nilainya diantara 0 - 5
# Setara dengan di excel: COUNTIFS(XX:YY, kondisi1, kondisi2, ..., kondisi_n) !!
"""

#Tarik data apabila kondisinya data sama dengan 0
#Jumlahin semua yang memenuhi kondisi tersebut

condition1 = (dataFrameTwitter["retweets_count"] == 0) 
total1 = np.sum(condition1) 

condition2 = (dataFrameTwitter["retweets_count"] == 1)
total2 = np.sum(condition2)

condition3 = (dataFrameTwitter["retweets_count"] == 2)
total3 = np.sum(condition3)

condition4 = (dataFrameTwitter["retweets_count"] == 3)
total4 = np.sum(condition4)

condition5 = (dataFrameTwitter["retweets_count"] >=4) & (dataFrameTwitter["retweets_count"] <=10)
total5 = np.sum(condition5)

plotDf = pd.DataFrame(
    [["0",total1],["1",total2],["2",total3],["3",total4],["4",total5]], #kolom
    columns=["number","counts"] #judul kolom
)

ax = sns.lineplot(x="number", y="counts", data=plotDf) #sns adalah seaborn, komponen buat tunjukin graf di python!

# %%
dataFrameTwitter.sort_values(by="retweets_count", ascending=False)
# Out:
#           username                                              tweet  \
# 12703    jokoanwar  selamat indonesia selamat pemerintah indonesia...
# 21395   widassatyo  narasi new normal berbahaya pemerintah tugasny...
# 26357       jokowi  pemerintah mengalokasikan dana rp677 2 triliun...
# 16632     vctrkmng                     pemerintah menghadapi covid 19
# 1204        jokowi  fokus kerja pemerintah menangani mengendalikan...
# ...            ...                                                ...
# 15388    dianunung  angka angka diekspose anies kecurigaannya kema...
# 15387    dianunung  menarik kesimpulan lonjakan pemakaman kematian...
# 15386    mgt_radio  pemerintah menteri koordinator bidang politik ...
# 15385  ptempursari  ikuti anjuran protokol pemerintah pencegahan c...
# 18464     saddeksh  lihat artikel berita nya ramai ceunah bela bel...
#
#        retweets_count  likes_count  \
# 12703            4084         7563
# 21395            1926         2879
# 26357            1817        17659
# 16632            1671         2865
# 1204             1669        12304
# ...               ...          ...
# 15388               0            0
# 15387               0            0
# 15386               0            1
# 15385               0            0
# 18464               0            0
#
#                                               translated   timestamps
# 12703  congratulations indonesia congratulations the ...  15900873840
# 21395  the new normal narrative is dangerous for the ...  15904852780
# 26357  the government allocates rp677 2 trillion in f...  15922134000
# 16632                      the government faces covid 19  15898472480
# 1204   the focus of government work addressing contro...  15887953720
# ...                                                  ...          ...
# 15388  figures exposed anies suspicion of death due t...  15899036850
# 15387  draw conclusions surge in funeral deaths due t...  15899036930
# 15386  government minister coordinator in the field o...  15899037030
# 15385  follow the recommendations of the covid preven...  15899037390
# 18464  see the news article is crowded ceunah defends...  15907046250
#
# [36929 rows x 6 columns]

# %%
dataFrameTwitter.sort_values(by="likes_count", ascending=False)
# Out:
#              username                                              tweet  \
# 26357          jokowi  pemerintah mengalokasikan dana rp677 2 triliun...
# 17990          jokowi  pemerintah fokus menangani pandemi covid 19 ag...
# 1204           jokowi  fokus kerja pemerintah menangani mengendalikan...
# 1118           jokowi  situasinya extraordinary kecepatan ketepatan m...
# 12703       jokoanwar  selamat indonesia selamat pemerintah indonesia...
# ...               ...                                                ...
# 15055     alineadotid           pemerintah kepastian 11 891 pdp covid 19
# 15054    aepsabdullah  pemerintah kenalkan 4 sehat 5 sempurna covid 1...
# 15053          satsmd  mencegah penyebaran covid 19 kota samarinda ma...
# 15052  kpukabpasuruan  sosialisasikan juknis wfh aplikasi zoom meetin...
# 18464        saddeksh  lihat artikel berita nya ramai ceunah bela bel...
#
#        retweets_count  likes_count  \
# 26357            1817        17659
# 17990            1329        14767
# 1204             1669        12304
# 1118              968         9212
# 12703            4084         7563
# ...               ...          ...
# 15055               0            0
# 15054               0            0
# 15053               0            0
# 15052               0            0
# 18464               0            0
#
#                                               translated   timestamps
# 26357  the government allocates rp677 2 trillion in f...  15922134000
# 17990  the government focused on handling the covid p...  15907605750
# 1204   the focus of government work addressing contro...  15887953720
# 1118   the situation is extraordinary the speed of ac...  15887992930
# 12703  congratulations indonesia congratulations the ...  15900873840
# ...                                                  ...          ...
# 15055           government certainty 11 891 pdp covid 19  15899186930
# 15054  the government introduces 4 healthy 5 perfect ...  15899187390
# 15053  prevent the spread of covid 19 samarinda citie...  15899188690
# 15052  socialize technical guidelines wfh zoom meetin...  15899189600
# 18464  see the news article is crowded ceunah defends...  15907046250
#
# [36929 rows x 6 columns]

# %%
dataFrameTwitter.sort_values(by="replies_count", ascending=False)
# Out:
#              username                                              tweet  \
# 26357          jokowi  pemerintah mengalokasikan dana rp677 2 triliun...
# 17990          jokowi  pemerintah fokus menangani pandemi covid 19 ag...
# 1204           jokowi  fokus kerja pemerintah menangani mengendalikan...
# 1118           jokowi  situasinya extraordinary kecepatan ketepatan m...
# 7249    andre_rosiade  rakyat susah badan penyelenggara jaminan sosia...
# ...               ...                                                ...
# 14181  polsekbanjaran  bhayangkara pembina keamanan ketertiban masyar...
# 14180      yoshyosh12  slesei maaf manusia model dikasih pringatan ke...
# 14178   sabhararespsp  ikuti imbauan pemerintah mudik kebaikan memutu...
# 14177    semang4tb4ng  patuhi aturan pemerintah mudik keluarga lingku...
# 36928       intandwbp  keluyurann rumah pekerjaan beli sembako jalan ...
#
#        replies_count  retweets_count  likes_count  \
# 26357           2475            1817        17659
# 17990           1452            1329        14767
# 1204            1106            1669        12304
# 1118            1011             968         9212
# 7249             763             166          877
# ...              ...             ...          ...
# 14181              0               0            1
# 14180              0               0            0
# 14178              0               0            0
# 14177              0               0            0
# 36928              0               5           28
#
#                                               translated   timestamps
# 26357  the government allocates rp677 2 trillion in f...  15922134000
# 17990  the government focused on handling the covid p...  15907605750
# 1204   the focus of government work addressing contro...  15887953720
# 1118   the situation is extraordinary the speed of ac...  15887992930
# 7249   the people are difficult social security organ...  15894915690
# ...                                                  ...          ...
# 14181  bhayangkara, the coach of the security of the ...  15899780210
# 14180  finished sorry man model given a warning hard ...  15899780960
# 14178  follow the government's call back and forth go...  15899781550
# 14177  obey the rules of the homecoming government fa...  15899782600
# 36928  wandering around the house of work buying groc...  15952082820
#
# [36929 rows x 7 columns]
